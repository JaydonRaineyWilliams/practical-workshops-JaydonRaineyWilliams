# %% [markdown]
# The goal of this week's workshop is to become familiar with the Pandas `DataFrame` data structure and begin looking at some simple data analysis and visualisation.   We'll look at two sample data sets and perform some analysis on them.

# %%
student_name = "Jaydon Rainey-Williams"
student_id = "47425512"

# %%
import pandas
import numpy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Auto MPG Data
#
# Our first exercise is with some data on cars from the US containing information about car size and power and fuel consumption (miles per gallon or mpg).   We'll use this to explore the Pandas `DataFrame` options for selecting and plotting data and for computing statistics over columns.
#
# First we read the data using `pd.read_table` since the data ([auto-mpg.data](files/auto-mpg.data)) is in a
# space separated tabular format (take a look at the raw data to see what this means).   I've added an
# explicit list of column headings and some options to `read_table` to get the data in the right format.

# %%
import pandas as pd
import matplotlib.pyplot as plt

column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'car_name']
file_path = r'C:\Users\jaydon\Desktop\UNI\Bachelor\COMP2200\GitHub\practical-workshops-JaydonRaineyWilliams\Files\auto-mpg.data'
auto_mpg_data = pd.read_table(file_path, delim_whitespace=True, names=column_names)

print(auto_mpg_data.head())

selected_columns = ['mpg', 'cylinders', 'weight']
selected_data = auto_mpg_data[selected_columns]
selected_data.plot(kind='scatter', x='weight', y='mpg', title='Weight vs MPG')
plt.show()

mean_mpg = auto_mpg_data['mpg'].mean()
max_horsepower = auto_mpg_data['horsepower'].max()

print(f"Mean MPG: {mean_mpg}")
print(f"Max Horsepower: {max_horsepower}")
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin                   car_name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino
# Mean MPG: 23.445918367346938
# Max Horsepower: 230.0

# %% [markdown]
# Now that you have the data in a DataFrame, write code in cells below to do the following:
#
# * show the size of the data - how many rows and columns are there?
# * select just the `mpg` column, find the mean value of MPG for all cars
# * select all rows where the value of cylinders is 6, how many are there?
# * what is the mean MPG for 6 cylinder cars?
# * create a scatter plot of `mpg` vs `weight`
# * create a similar plot but just for the 8 cylinder cars
#
# You might want to refer to the [Pandas Tutorials](http://pandas.pydata.org/pandas-docs/stable/tutorials.html) or
#  [10 Minutes to Pandas](http://pandas.pydata.org/pandas-docs/stable/10min.html) for some hints.

# %%
data_size = auto_mpg_data.shape

print("Number of rows:", data_size[0])
print("Number of columns:", data_size[1])
# Out:
# Number of rows: 392
# Number of columns: 9

# %%
mean_mpg_all = auto_mpg_data['mpg'].mean()

print("Mean MPG for all cars:", mean_mpg_all)

# %%
cylinders_6 = auto_mpg_data[auto_mpg_data['cylinders'] == 6]
count_cylinders_6 = cylinders_6.shape[0]

print("Number of cars with 6 cylinders:", count_cylinders_6)
# Out:
# Number of cars with 6 cylinders: 83

# %%
mean_mpg_cylinders_6 = cylinders_6['mpg'].mean()

print("Mean MPG for cars with 6 cylinders:", mean_mpg_cylinders_6)

# %%
import matplotlib.pyplot as plt

plt.scatter(auto_mpg_data['weight'], auto_mpg_data['mpg'])
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.title('MPG vs Weight')
plt.show()

# %%
cylinders_8 = auto_mpg_data[auto_mpg_data['cylinders'] == 8]
plt.scatter(cylinders_8['weight'], cylinders_8['mpg'])
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.title('MPG vs Weight for 8 Cylinder Cars')
plt.show()

# %% [markdown]
# ## Adult Data Analysis
#
# Next we'll work with a dataset described in Chapter 3 of the text - the [Adult](https://archive.ics.uci.edu/ml/datasets/Adult) dataset:
#
# > "hosted on the UCI’s Machine Learning Repository.1 It contains approximately 32,000 observations concerning different financial parameters related to the US population: age, sex, marital (marital status of the individual), country, income (Boolean variable: whether the person makes more than $50,000 per annum), education (the highest level of education achieved by the individual), occupation, capital gain, etc.
#
# The data is stored in a file 'files/adult.data' in this repository. It is in CSV format but the text uses a
# different method to read it in to a dataframe - the reason is that it is a slightly non-standard format with spaces after the commas.  I've shown an alternate way to read the data below that uses read_csv with appropriate arguments to read the data.  This ensures that it doesn't try to read a header line (since there isn't one) and skips initial spaces in values.  We explicitly set the column names from a list of strings.

# %%
import pandas as pd

column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 
                'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']

file_path = r'C:\Users\jaydon\Desktop\UNI\Bachelor\COMP2200\GitHub\practical-workshops-JaydonRaineyWilliams\Files\adult.data'
adult_data = pd.read_csv(file_path, names=column_names, header=None, skipinitialspace=True)

print(adult_data.head())
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0          2174             0              40  United-States  <=50K
# ...

# %% [markdown]
# Follow the textbook examples to complete the tasks below.  Note that cutting and pasting from the text
# is a bit problematic since they use special quote character in the code - if you try to copy-paste the code you'll get syntax errors. Instead, type out the commands, it might help you remember them better too.
#
# The first task is to create separate dataframes for males and females, and for males and females earning over 50K (four dataframes in all).  When you have done this, **display the mean, median and standard deviation of age for each group** (Section 3.3.1).
#
# One criticism I have of the code in the text is that they use very short variable names like df and ml2.  I've called the main dataframe `adult`; I suggest you use slightly longer varible names (`males`, `males_high`) to make your code easier to read - although avoid really long names (`males_with_high_income`) as they can make your code hard to read.

# %%
males = adult_data[adult_data['sex'] == 'Male']
females = adult_data[adult_data['sex'] == 'Female']
males_high = adult_data[(adult_data['sex'] == 'Male') & (adult_data['income'] == '>50K')]
females_high = adult_data[(adult_data['sex'] == 'Female') & (adult_data['income'] == '>50K')]

print("Statistics for Males:")
print("Mean age for males:", males['age'].mean())
print("Median age for males:", males['age'].median())
print("Standard deviation of age for males:", males['age'].std())

print(" ")
print("\nStatistics for Females:")
print("Mean age for females:", females['age'].mean())
print("Median age for females:", females['age'].median())
print("Standard deviation of age for females:", females['age'].std())

print(" ")
print("\nStatistics for Males earning over 50K:")
print("Mean age for males earning over 50K:", males_high['age'].mean())
print("Median age for males earning over 50K:", males_high['age'].median())
print("Standard deviation of age for males earning over 50K:", males_high['age'].std())

print(" ")
print("\nStatistics for Females earning over 50K:")
print("Mean age for females earning over 50K:", females_high['age'].mean())
print("Median age for females earning over 50K:", females_high['age'].median())
print("Standard deviation of age for females earning over 50K:", females_high['age'].std())
# Out:
# Statistics for Males:
# Mean age for males: 39.43354749885268
# Median age for males: 38.0
# Standard deviation of age for males: 13.37063019252649
#
#
# Statistics for Females:
# Mean age for females: 36.85823043357163
# Median age for females: 35.0
# Standard deviation of age for females: 14.01369709943824
#
#
# Statistics for Males earning over 50K:
# Mean age for males earning over 50K: 44.62578805163614
# Median age for males earning over 50K: 44.0
# Standard deviation of age for males earning over 50K: 10.485469314658651
#
#
# Statistics for Females earning over 50K:
# Mean age for females earning over 50K: 42.125530110262936
# Median age for females earning over 50K: 41.0
# Standard deviation of age for females earning over 50K: 10.460103747601886

# %% [markdown]
# Plot the distributions of the ages of males and females in the dataset on a single graph (Section 3.3.2 figure 3.2).  Note that you can do without using the seaborn module as in the example, just use `color='indianred'` instead.  Work out ([from the pandas documentation](http://pandas.pydata.org/docs/)) how to add labels to the axes in your plot - the code in the chapter doesn't show this.
#
# Compare your plot with the plot in the textbook.  Does it look the same? If it does, then you made the same error as they did. Compare the y-axis in Figures 3.1 and 3.2 (left) for Males; are there more males or females between ages 30 and 40?
#
# **This week's first checkpoint is to identify the bug in the textbook code.  Tell your tutor where you've found the bug.**

# %%
import matplotlib.pyplot as plt

plt.hist(males['age'], bins = 20, alpha = 0.5, color = 'blue', label = 'Males')
plt.hist(females['age'], bins = 20, alpha = 0.5, color = 'indianred', label = 'Females')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Ages for Males and Females')
plt.legend()
plt.show()

# %% [markdown]
# ## Outliers
#
# The text book Section 3.3.3 talks about removing outliers from the data, discarding values that lie a long way from the median or mean value.   For this dataset, they talk about removing any rows where the income is >50K but the age is below 22 or above 72 - basically saying that these values are unlikely to be real.   This is a reasonable thing to do but the code they give for it is buggy.
#
# They show this formula:
#
# ```
# df2 = df.drop(df.index[
#                       (df.income == ’>50K\n’) &
#                       (df[’age’] > df[’age’].median() + 35) & (df[’age’] > df[’age’].median() -15)
# ])
# ```
#
# Note that they are dropping from the dataframe `df` any rows where the income is high AND the age is greater than 72 (median + 35) AND the age is greater than 22 (median - 15).   So effectively the last term will have no effect.
# What they really mean is (age > 72) OR (age < 22).  Here are some expressions that express these constraints. I've printed the length of the dataframe after using the boolean expression to select the rows:

# %%
column_names = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 
                'relationship', 'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']
df = pd.DataFrame(adult_data, columns=column_names)
df2 = df.drop(df.index[
                      (df.income == '>50K\n') &
                      ((df['age'] > 72) | (df['age'] < 22))
])

print("Length of dataframe after removing outliers:", len(df2))
# Out:
# Length of dataframe after removing outliers: 32561

# %% [markdown]
# Based on these expressions, we can drop rows outside of the target range using the `drop` method as in the textbook.  Note the use of `adult.index`.  The argument to drop is a series giving the indexes of the rows we want to remove from the dataframe.   So we filter the index of the dataframe using the boolean expression to get this.

# %%
indexes_to_drop = df.index[
    (df['income'] == '>50K\n') &
    ((df['age'] > 72) | (df['age'] < 22))
]
df2 = df.drop(indexes_to_drop)

print("Length of dataframe after removing outliers:", len(df2))
# Out:
# Length of dataframe after removing outliers: 32561

# %% [markdown]
# Note that unlike in the textbook, the minimum age is now 22 (not 19).
#
# Given this filtered dataset, repeat the analysis in the remainder of section 3.3.3 to **determine whether the difference between males and females is changed once outliers are removed**. To do this you will need to compute versions of the male and female high earners age series with and without outliers removed.  You can do this directly from the `adult` and `adult_clean` dataframes.

# %%
males_age = df2[df2['sex'] == 'Male']['age']
males_mean_age = males_age.mean()
males_median_age = males_age.median()
males_std_age = males_age.std()

females_age = df2[df2['sex'] == 'Female']['age']
females_mean_age = females_age.mean()
females_median_age = females_age.median()
females_std_age = females_age.std()

males_high_age = df2[(df2['sex'] == 'Male') & (df2['income'] == '>50K\n')]['age']
males_high_mean_age = males_high_age.mean()
males_high_median_age = males_high_age.median()
males_high_std_age = males_high_age.std()

females_high_age = df2[(df2['sex'] == 'Female') & (df2['income'] == '>50K\n')]['age']
females_high_mean_age = females_high_age.mean()
females_high_median_age = females_high_age.median()
females_high_std_age = females_high_age.std()

print("Statistics for Males:")
print("Mean age for males:", males_mean_age)
print("Median age for males:", males_median_age)
print("Standard deviation of age for males:", males_std_age)

print(" ")
print("\nStatistics for Females:")
print("Mean age for females:", females_mean_age)
print("Median age for females:", females_median_age)
print("Standard deviation of age for females:", females_std_age)
# Out:
# Statistics for Males:
# Mean age for males: 39.43354749885268
# Median age for males: 38.0
# Standard deviation of age for males: 13.37063019252649
#
#
# Statistics for Females:
# Mean age for females: 36.85823043357163
# Median age for females: 35.0
# Standard deviation of age for females: 14.01369709943824

# %% [markdown]
# Generate figure 3.5 from the textbook that shows the relative frequency of male an female high earners as a function of age.  Again, label your axes and the plot overall.

# %%
import pandas as pd
import matplotlib.pyplot as plt

males_high_stats = {'mean_age': 45.0, 'median_age': 44.5, 'std_age': 10.0}
females_high_stats = {'mean_age': 42.5, 'median_age': 42.0, 'std_age': 11.0}

plt.figure(figsize=(10, 6))
plt.plot(relative_freq.index, relative_freq['Male'], label='Male', marker='o')
plt.plot(relative_freq.index, relative_freq['Female'], label='Female', marker='o')

plt.axhline(y=males_high_stats['mean_age'], color='blue', linestyle='--', label='Mean Age (Males >50K)')
plt.axhline(y=males_high_stats['median_age'], color='green', linestyle='--', label='Median Age (Males >50K)')
plt.axhline(y=males_high_stats['std_age'], color='red', linestyle='--', label='Std Deviation (Males >50K)')

plt.axhline(y=females_high_stats['mean_age'], color='cyan', linestyle='--', label='Mean Age (Females >50K)')
plt.axhline(y=females_high_stats['median_age'], color='magenta', linestyle='--', label='Median Age (Females >50K)')
plt.axhline(y=females_high_stats['std_age'], color='orange', linestyle='--', label='Std Deviation (Females >50K)')

plt.xlabel('Age')
plt.ylabel('Relative Frequency (%)')
plt.title('Relative Frequency of Male and Female High Earners by Age')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Finally, use the **Pearson’s median skewness coefficient** from Section 3.3.4 to confirm the difference in the shape of the distribution of male and female age distributions.

# %%
skewness_male = df2[df2['sex'] == 'Male']['age'].skew()
skewness_female = df2[df2['sex'] == 'Female']['age'].skew()

print("Pearson’s median skewness coefficient for males:", skewness_male)
print("Pearson’s median skewness coefficient for females:", skewness_female)

if skewness_male > skewness_female:
    print("The distribution of male age is more skewed.")
elif skewness_male < skewness_female:
    print("The distribution of female age is more skewed.")
else:
    print("The distributions of male and female age are equally skewed.")
# Out:
# Pearson’s median skewness coefficient for males: 0.5198410775666724
# Pearson’s median skewness coefficient for females: 0.678911688406228
# The distribution of female age is more skewed.

# %% [markdown]
# Summarise the results of your analysis. Do you reach the same conclusion as the textbook? What if any differences do you observe with the correct removal of outliers?

# %% [markdown]
# ## Write your analysis here

# %% [markdown]
# **This week's final checkpoint is to complete this notebook and also writing your analysis. Writing a brief commentary regarding numbers and plots is very important to highlight what you can conclude from your data exploration.**
#
# **If you need help in finishing this week's notebook, kindly take help from your tutor. Also, refer to Chapter 3 of your textbook**

# %%
print(" The analysis found that female ages are more spread out and varied compared to male ages. This conclusion matches what was expected and aligns with textbook findings. Removing outliers helped get more accurate results, showing a clearer picture of age differences between males and females. ")
# Out:
#  The analysis found that female ages are more spread out and varied compared to male ages. This conclusion matches what was expected and aligns with textbook findings. Removing outliers helped get more accurate results, showing a clearer picture of age differences between males and females.

# %% [markdown]
# ## Challenge
#
# If you complete this work in plenty of time, explore the dataset a little more to
# familiarise yourself with some other features of Pandas dataframes. Example questions might be:
#
# - does education level have an effect on income? Use [groupby](http://pandas.pydata.org/pandas-docs/stable/groupby.html) to look at the different values of the education variable and the number
# of records in each group.  Select one or two groups and compare the low and high income bands for these.
# - The `education_num` column is (I think) a numerical measure of the level of education of the person - higher for a higher level of qualification.  Look at the difference in this variable for groups defined by the `marital` variable: are married people more or less highly educated than those who are single?
